# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
superbowl_viewers = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_viewers.csv")
superbowl_outcome = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_outcome.csv")
superbowl_afcvnfc = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_afcvnfc.csv")
superbowl_attendance = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_attendance.csv")
superbowl_all_games = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/Team_Record_All_Games.csv")
superbowl_capacity = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_capacity.csv")
superbowl_viewers
# Out:
#    Super Bowl  Season         Date Network  Rating  Share  Second Spot  \
# 0         LII  2017.0   Feb 4 2018     NBC    43.1   68.0  $5,200,000
# 1          LI  2016.0   Feb 5 2017     FOX    45.3   70.0  $5,000,000
# 2           L  2015.0   Feb 7 2016     CBS    46.6   72.0  $4,500,000
# 3        XLIX  2014.0   Feb 1 2015     NBC    47.5   71.0  $4,250,000
# 4      XLVIII  2013.0   Feb 2 2014     FOX    46.7   69.0  $4,000,000
# 5       XLVII  2012.0   Feb 3 2013     CBS    48.1   71.0  $3,800,000
# 6        XLVI  2011.0   Feb 5 2012     NBC    47.8   71.0  $3,500,000
# 7         XLV  2010.0   Feb 6 2011     FOX    47.9   68.0  $3,100,000
# 8        XLIV  2009.0   Feb 7 2010     CBS    45.0   66.0  $2,954,010
# 9       XLIII  2008.0   Feb 1 2009     FOX    42.0   64.0  $2,999,960
# 10       XLII  2007.0   Feb 3 2008     FOX    43.1   65.0  $2,699,963
# 11        XLI  2006.0   Feb 4 2007     CBS    42.6   64.0  $2,385,365
# ...

# %%
df = pd.merge(superbowl_afcvnfc, superbowl_attendance, on="Season")
df
# Out:
#     Season  AFC  NFC  Tie       Date       SB  Attendance          QB  Winner  \
# 0     2017   23   41    0   4-Feb-18      LII       67612          Nick Foles
# 1     2016   33   30    1   5-Feb-17      LI        70807           Tom Brady
# 2     2015   29   35    0   7-Feb-16       L        71088      Peyton Manning
# 3     2014   33   30    1   1-Feb-15     XLIX       70288           Tom Brady
# 4     2013   30   34    0   2-Feb-14   XLVIII       82529      Russell Wilson
# 5     2012   25   39    0   3-Feb-13    XLVII       71024          Joe Flacco
# 6     2011   31   33    0   5-Feb-12     XLVI       68658         Eli Manning
# 7     2010   34   30    0   6-Feb-11      XLV      103219       Aaron Rodgers
# 8     2009   37   27    0   7-Feb-10     XLIV       74059          Drew Brees
# 9     2008   34   29    1   1-Feb-09    XLIII       70774  Ben Roethlisberger
# 10    2007   32   32    0   3-Feb-08     XLII       71101         Eli Manning
# ...

# %%
df = df[["Season", "AFC", "NFC", "Tie","Date", "SB", "Winner", "City", "State", "Attendance"]]
df
# Out:
#     Season  AFC  NFC  Tie       Date       SB                Winner  \
# 0     2017   23   41    0   4-Feb-18      LII   Philadelphia Eagles
# 1     2016   33   30    1   5-Feb-17      LI   New England Patriots
# 2     2015   29   35    0   7-Feb-16       L         Denver Broncos
# 3     2014   33   30    1   1-Feb-15     XLIX  New England Patriots
# 4     2013   30   34    0   2-Feb-14   XLVIII      Seattle Seahawks
# 5     2012   25   39    0   3-Feb-13    XLVII      Baltimore Ravens
# 6     2011   31   33    0   5-Feb-12     XLVI       New York Giants
# 7     2010   34   30    0   6-Feb-11      XLV     Green Bay Packers
# 8     2009   37   27    0   7-Feb-10     XLIV    New Orleans Saints
# 9     2008   34   29    1   1-Feb-09    XLIII   Pittsburgh Steelers
# 10    2007   32   32    0   3-Feb-08     XLII       New York Giants
# 11    2006   40   24    0   4-Feb-07      XLI    Indianapolis Colts
# 12    2005   34   30    0   5-Feb-06       XL   Pittsburgh Steelers
# ...

# %%
df = pd.merge(df, superbowl_viewers, on="Season")
df
# Out:
#     Season  AFC  NFC  Tie     Date_x       SB                Winner  \
# 0     2017   23   41    0   4-Feb-18      LII   Philadelphia Eagles
# 1     2016   33   30    1   5-Feb-17      LI   New England Patriots
# 2     2015   29   35    0   7-Feb-16       L         Denver Broncos
# 3     2014   33   30    1   1-Feb-15     XLIX  New England Patriots
# 4     2013   30   34    0   2-Feb-14   XLVIII      Seattle Seahawks
# 5     2012   25   39    0   3-Feb-13    XLVII      Baltimore Ravens
# 6     2011   31   33    0   5-Feb-12     XLVI       New York Giants
# 7     2010   34   30    0   6-Feb-11      XLV     Green Bay Packers
# 8     2009   37   27    0   7-Feb-10     XLIV    New Orleans Saints
# 9     2008   34   29    1   1-Feb-09    XLIII   Pittsburgh Steelers
# 10    2007   32   32    0   3-Feb-08     XLII       New York Giants
# 11    2006   40   24    0   4-Feb-07      XLI    Indianapolis Colts
# 12    2005   34   30    0   5-Feb-06       XL   Pittsburgh Steelers
# ...

# %%
df["column1"] = df["column1"].str.replace(',','')
df["column1"] = pd.to_numeric(df["column1"])
df
# Out:
#     Season  AFC  NFC  Tie     Date_x       SB                Winner  \
# 0     2017   23   41    0   4-Feb-18      LII   Philadelphia Eagles
# 1     2016   33   30    1   5-Feb-17      LI   New England Patriots
# 2     2015   29   35    0   7-Feb-16       L         Denver Broncos
# 3     2014   33   30    1   1-Feb-15     XLIX  New England Patriots
# 4     2013   30   34    0   2-Feb-14   XLVIII      Seattle Seahawks
# 5     2012   25   39    0   3-Feb-13    XLVII      Baltimore Ravens
# 6     2011   31   33    0   5-Feb-12     XLVI       New York Giants
# 7     2010   34   30    0   6-Feb-11      XLV     Green Bay Packers
# 8     2009   37   27    0   7-Feb-10     XLIV    New Orleans Saints
# 9     2008   34   29    1   1-Feb-09    XLIII   Pittsburgh Steelers
# 10    2007   32   32    0   3-Feb-08     XLII       New York Giants
# 11    2006   40   24    0   4-Feb-07      XLI    Indianapolis Colts
# 12    2005   34   30    0   5-Feb-06       XL   Pittsburgh Steelers
# ...

# %%
df["Viewers (MM)"] = df["Viewers"] / 1000000
df
# Out:
#     Season  AFC  NFC  Tie     Date_x       SB                Winner  \
# 0     2017   23   41    0   4-Feb-18      LII   Philadelphia Eagles
# 1     2016   33   30    1   5-Feb-17      LI   New England Patriots
# 2     2015   29   35    0   7-Feb-16       L         Denver Broncos
# 3     2014   33   30    1   1-Feb-15     XLIX  New England Patriots
# 4     2013   30   34    0   2-Feb-14   XLVIII      Seattle Seahawks
# 5     2012   25   39    0   3-Feb-13    XLVII      Baltimore Ravens
# 6     2011   31   33    0   5-Feb-12     XLVI       New York Giants
# 7     2010   34   30    0   6-Feb-11      XLV     Green Bay Packers
# 8     2009   37   27    0   7-Feb-10     XLIV    New Orleans Saints
# 9     2008   34   29    1   1-Feb-09    XLIII   Pittsburgh Steelers
# 10    2007   32   32    0   3-Feb-08     XLII       New York Giants
# 11    2006   40   24    0   4-Feb-07      XLI    Indianapolis Colts
# 12    2005   34   30    0   5-Feb-06       XL   Pittsburgh Steelers
# ...

# %%
df["NFC-AFC Wins"] = df["NFC"] - df["AFC"]
df
# Out:
#     Season  AFC  NFC  Tie     Date_x       SB                Winner  \
# 0     2017   23   41    0   4-Feb-18      LII   Philadelphia Eagles
# 1     2016   33   30    1   5-Feb-17      LI   New England Patriots
# 2     2015   29   35    0   7-Feb-16       L         Denver Broncos
# 3     2014   33   30    1   1-Feb-15     XLIX  New England Patriots
# 4     2013   30   34    0   2-Feb-14   XLVIII      Seattle Seahawks
# 5     2012   25   39    0   3-Feb-13    XLVII      Baltimore Ravens
# 6     2011   31   33    0   5-Feb-12     XLVI       New York Giants
# 7     2010   34   30    0   6-Feb-11      XLV     Green Bay Packers
# 8     2009   37   27    0   7-Feb-10     XLIV    New Orleans Saints
# 9     2008   34   29    1   1-Feb-09    XLIII   Pittsburgh Steelers
# 10    2007   32   32    0   3-Feb-08     XLII       New York Giants
# 11    2006   40   24    0   4-Feb-07      XLI    Indianapolis Colts
# 12    2005   34   30    0   5-Feb-06       XL   Pittsburgh Steelers
# ...

# %%
df["AFC-NFC Wins"] = df["AFC"] - df["NFC"]
df
# Out:
#     Season  AFC  NFC  Tie     Date_x       SB                Winner  \
# 0     2017   23   41    0   4-Feb-18      LII   Philadelphia Eagles
# 1     2016   33   30    1   5-Feb-17      LI   New England Patriots
# 2     2015   29   35    0   7-Feb-16       L         Denver Broncos
# 3     2014   33   30    1   1-Feb-15     XLIX  New England Patriots
# 4     2013   30   34    0   2-Feb-14   XLVIII      Seattle Seahawks
# 5     2012   25   39    0   3-Feb-13    XLVII      Baltimore Ravens
# 6     2011   31   33    0   5-Feb-12     XLVI       New York Giants
# 7     2010   34   30    0   6-Feb-11      XLV     Green Bay Packers
# 8     2009   37   27    0   7-Feb-10     XLIV    New Orleans Saints
# 9     2008   34   29    1   1-Feb-09    XLIII   Pittsburgh Steelers
# 10    2007   32   32    0   3-Feb-08     XLII       New York Giants
# 11    2006   40   24    0   4-Feb-07      XLI    Indianapolis Colts
# 12    2005   34   30    0   5-Feb-06       XL   Pittsburgh Steelers
# ...

# %%
superbowl_all_games_T = superbowl_all_games.transpose()
superbowl_all_games_T
# Out:
#       0        1         2         3        4        5         6      7   \
# 0   NAME  COWBOYS  STEELERS  PATRIOTS  BRONCOS  VIKINGS  DOLPHINS  49ERS
# 1   1995       15        13         6        8        8         9     11
# 2   1996       11        11        13       13        9         8     13
# 3   1997        6        12        11       16       10         9     14
# 4   1998       10         7         9       17       16        11     13
# 5   1999        8         6         8        6       11        10      4
# 6   2000        5         9         5       11       12        12      6
# 7   2001        5        14        14        8        5        11     12
# 8   2002        5        11         9        9        6         9     11
# 9   2003       10         6        17       10        9        10      7
# 10  2004        6        16        17       10        9         4      2
# 11  2005        9        15        11       14        9         9      4
# ...

# %%
superbowl_all_games_T.to_csv(path_or_buf="/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_all_games_T.csv", index=False)

# %%
superbowl_all_games_T = pd.read_csv("/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_all_games_T.csv")
superbowl_all_games_T
# Out:
#        0        1         2         3        4        5         6      7  \
# 0   NAME  COWBOYS  STEELERS  PATRIOTS  BRONCOS  VIKINGS  DOLPHINS  49ERS
# 1   1995       15        13         6        8        8         9     11
# 2   1996       11        11        13       13        9         8     13
# 3   1997        6        12        11       16       10         9     14
# 4   1998       10         7         9       17       16        11     13
# 5   1999        8         6         8        6       11        10      4
# 6   2000        5         9         5       11       12        12      6
# 7   2001        5        14        14        8        5        11     12
# 8   2002        5        11         9        9        6         9     11
# 9   2003       10         6        17       10        9        10      7
# 10  2004        6        16        17       10        9         4      2
# 11  2005        9        15        11       14        9         9      4
# ...

# %%
superbowl_capacity
# Out:
#    Superbowl       Year                          Arena  Capacity  Attendees  \
# 0        XXX  28-Jan-96              Sun Devil Stadium     56600      76347
# 1       XXXI  26-Jan-97            Louisiana Superdome     74295      72301
# 2      XXXII  25-Jan-98               Qualcomm Stadium     70561      68912
# 3     XXXIII  31-Jan-99             Pro Player Stadium     65326      74803
# 4      XXXIV  30-Jan-00                   Georgia Dome     92746      72625
# 5       XXXV  28-Jan-01          Raymond James Stadium     65890      71921
# 6      XXXVI   3-Feb-02            Louisiana Superdome     74295      72922
# 7     XXXVII  26-Jan-03               Qualcomm Stadium     70561      67603
# 8    XXXVIII   1-Feb-04                Reliant Stadium     72220      71525
# 9      XXXIX   6-Feb-05                 Alltel Stadium     67164      78125
# 10        XL   5-Feb-06                    Ford Field      65000      68206
# ...

# %%
superbowl_capacity["Capacity"] = pd.to_numeric(superbowl_capacity["Capacity"])
superbowl_capacity["Capacity"] = superbowl_capacity["Capacity"].str.replace(',','')
superbowl_capacity
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-569-ca418d6cd27d> in <module>
#       1 superbowl_capacity["Capacity"] = pd.to_numeric(superbowl_capacity["Capacity"])
# ----> 2 superbowl_capacity["Capacity"] = superbowl_capacity["Capacity"].str.replace(',','')
#       3 superbowl_capacity
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# ...

# %%
superbowl_capacity["Attendees"] = superbowl_capacity["Attendees"].str.replace(',','')
superbowl_capacity["Attendees"] = pd.to_numeric(superbowl_capacity["Attendees"])
superbowl_capacity
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-561-62b108b80712> in <module>
# ----> 1 superbowl_capacity["Attendees"] = superbowl_capacity["Attendees"].str.replace(',','')
#       2 superbowl_capacity["Attendees"] = pd.to_numeric(superbowl_capacity["Attendees"])
#       3 superbowl_capacity
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# ...

# %%
superbowl_capacity["Percent Filled"] = superbowl_capacity["Attendees"]/superbowl_capacity["Capacity"]
superbowl_capacity
# Out:
#    Superbowl       Year                          Arena  Capacity  Attendees  \
# 0        XXX  28-Jan-96              Sun Devil Stadium     56600      76347
# 1       XXXI  26-Jan-97            Louisiana Superdome     74295      72301
# 2      XXXII  25-Jan-98               Qualcomm Stadium     70561      68912
# 3     XXXIII  31-Jan-99             Pro Player Stadium     65326      74803
# 4      XXXIV  30-Jan-00                   Georgia Dome     92746      72625
# 5       XXXV  28-Jan-01          Raymond James Stadium     65890      71921
# 6      XXXVI   3-Feb-02            Louisiana Superdome     74295      72922
# 7     XXXVII  26-Jan-03               Qualcomm Stadium     70561      67603
# 8    XXXVIII   1-Feb-04                Reliant Stadium     72220      71525
# 9      XXXIX   6-Feb-05                 Alltel Stadium     67164      78125
# 10        XL   5-Feb-06                    Ford Field      65000      68206
# ...

# %%
superbowl_all_games_T
# Out:
# 1   1995  15  13   6   8   8   9  11  13   8  ...   7   8   4  10   5   7   0  \
# 1   1995  15  13   6   8   8   9  11  13   8  ...   7   8   4  10   5   7   0
# 2   1996  11  11  13  13   9   8  13  16   7  ...   8   7   7   5   0   6   4
# 3   1997   6  12  11  16  10   9  14  15   4  ...   7   8   4   9   0  11   6
# 4   1998  10   7   9  17  16  11  13  11   8  ...   3   8  10   5   0   8   6
# 5   1999   8   6   8   6  11  10   4   8   8  ...   4   9   6   8   2  12   8
# 6   2000   5   9   5  11  12  12   6   9  13  ...   4   6   3   9   3  10  16
# 7   2001   5  14  14   8   5  11  12  13  11  ...   6   9   7   2   7   9  11
# 8   2002   5  11   9   9   6   9  11  12  13  ...   2   7   5   3   9  15   7
# 9   2003  10   6  17  10   9  10   7  11   4  ...   8  10   4   5   5   7  10
# 10  2004   6  16  17  10   9   4   2  10   5  ...   8   9   6   6   4   5   9
# 11  2005   9  15  11  14   9   9   4   4   4  ...  11  15   5   5   6  11   6
# ...

# %%
#superbowl_all_games_T = superbowl_all_games_T.rename(columns={"NAME":"Season"})
#superbowl_all_games_T

# %%
superbowl_all_games_T.to_csv(path_or_buf="/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_all_games_T.csv", index=False)

# %%
#df.to_csv(path_or_buf="/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_full.csv", index=False)
superbowl_capacity.to_csv(path_or_buf="/Users/jlh/ucb-bel-data-pt-08-2020-u-c/Saved_Docs/Project_NFL/superbowl_capacity.csv", index=False)

# %%
x = df["Season"]
y = df["AFC"]
y2 = df["NFC"]
y3 = df["Viewers (MM)"]

fig, ax1 = plt.subplots()


afc_handle, = ax1.plot(x, y, color="r", label="AFC")
nfc_handle, = ax1.plot(x, y2, color="b", label="NFC")
plt.title("Interconference Record over Time")
plt.legend(loc="lower right")


ax2 = ax1.twinx()
sb_viewers, = ax2.plot(x, y3, color="g", label="Viewers")
plt.legend(loc="best")


plt.tight_layout()
plt.show()

# %%
#plt.figure(figsize=(17,5))
#nfc_handle, = plt.plot(x_years, y_sum_wins, color="c", label='NFC - AFC wins')
#plt.axhline(y=0, color="grey")
#plt.legend(loc="best")
#plt.xticks(ticks=x_years, rotation='vertical')
#plt.title("NFC - AFC Wins 1970-2017")
#plt.xlabel("Years")
#plt.ylabel("NFC - AFC Wins")
#plt.show()

####
#plt.figure(figsize=(17,5))
#nfc_handle, = plt.plot(x_years, y2_sum_wins, color="m", label='AFC - NFC wins')
#plt.axhline(y=0, color="grey")
#plt.legend(loc="best")
#plt.xticks(ticks=x_years, rotation='vertical')
#plt.title("AFC - NFC Wins 1970-2017")
#plt.xlabel("Years")
#plt.ylabel("AFC - NFC Wins")
#plt.show()

# %%
superbowl_all_games_T
# Out:
# 1   1995  15  13   6   8   8   9  11  13   8  ...   7   8   4  10   5   7   0  \
# 1   1995  15  13   6   8   8   9  11  13   8  ...   7   8   4  10   5   7   0
# 2   1996  11  11  13  13   9   8  13  16   7  ...   8   7   7   5   0   6   4
# 3   1997   6  12  11  16  10   9  14  15   4  ...   7   8   4   9   0  11   6
# 4   1998  10   7   9  17  16  11  13  11   8  ...   3   8  10   5   0   8   6
# 5   1999   8   6   8   6  11  10   4   8   8  ...   4   9   6   8   2  12   8
# 6   2000   5   9   5  11  12  12   6   9  13  ...   4   6   3   9   3  10  16
# 7   2001   5  14  14   8   5  11  12  13  11  ...   6   9   7   2   7   9  11
# 8   2002   5  11   9   9   6   9  11  12  13  ...   2   7   5   3   9  15   7
# 9   2003  10   6  17  10   9  10   7  11   4  ...   8  10   4   5   5   7  10
# 10  2004   6  16  17  10   9   4   2  10   5  ...   8   9   6   6   4   5   9
# 11  2005   9  15  11  14   9   9   4   4   4  ...  11  15   5   5   6  11   6
# ...
